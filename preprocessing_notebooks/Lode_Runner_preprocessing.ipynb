# %%
import os
import json
from typing import List, Dict, Generator, Tuple, Optional
import sys
sys.path.append(os.path.abspath('..')) 
from utils import find_txt_files

# %%
INPUT_DIRS: List[str] = [r'/home/pressprexx/Code/AKCITGaming/Paper_LLM_PCG_Geral/VGLC_LLM_Finetunning/TheVGLC/Lode Runner/Processed']

OUTPUT_FILE: str = 'lode_runner.json'

# %%
def process_level_and_generate_strings(filepath: str) -> Optional[Dict]:

    try:
        with open(filepath, 'r') as f:
            lines = [line.rstrip('\n') for line in f.readlines()]

        processed_lines = [line for line in lines if line]

        if not processed_lines:
            print(f"Skipping empty file: {os.path.basename(filepath)}")
            return None

        level_height = len(processed_lines)
        if level_height == 0:
             print(f"  Skipping file with no content after cleaning: {os.path.basename(filepath)}")
             return None
        level_width = len(processed_lines[0]) 

        inconsistent = [i for i, line in enumerate(processed_lines) if len(line) != level_width]
        if inconsistent:
            print(f"Inconsistent line widths, the level representation might be incorrect")
        print(f"Processing level with original dimensions: {level_height} height x {level_width} width.")

        str_horizontal_nosplit = "".join(processed_lines)
        str_horizontal_newline = "\n".join(processed_lines)
        str_horizontal_pipe = "|".join(processed_lines)

        vertical_cols = []
        for j in range(level_width):
            col_chars = []
            for i in range(level_height - 1, -1, -1):
                 if j < len(processed_lines[i]):
                     col_chars.append(processed_lines[i][j])
                 else:
                     col_chars.append('-')
            col_str = "".join(col_chars)
            vertical_cols.append(col_str)

        str_vertical_nosplit = "".join(vertical_cols)
        str_vertical_newline = "\n".join(vertical_cols)
        str_vertical_pipe = "|".join(vertical_cols)

        return {
            "source_file": os.path.basename(filepath),
            "level_lines": processed_lines, 
            "str_horizontal_nosplit": str_horizontal_nosplit,
            "str_horizontal_newline": str_horizontal_newline,
            "str_horizontal_pipe": str_horizontal_pipe,
            "str_vertical_nosplit": str_vertical_nosplit,
            "str_vertical_newline": str_vertical_newline,
            "str_vertical_pipe": str_vertical_pipe,
        }

    except FileNotFoundError:
        print(f"Error: File not found: {filepath}")
        return None
    except Exception as e:
        print(f"Error processing file {filepath}: {e}")
        return None

# %%
level_filepaths = find_txt_files(INPUT_DIRS)

all_levels_data = []
file_count = 0
processed_count = 0

for filepath in level_filepaths:
    file_count += 1
    print(f"\nProcessing file {file_count}/{len(level_filepaths)}: {os.path.basename(filepath)}")

    level_data = process_level_and_generate_strings(filepath)

    if level_data:
        all_levels_data.append(level_data)
        processed_count += 1
    else:
        print(f"  Skipped file {os.path.basename(filepath)} due to errors, empty content, or processing issues.")


print(f"Successfully processed {processed_count} out of {file_count} files.")

if processed_count > 0:
    print(f"\nWriting data to {OUTPUT_FILE}...")
    try:
        output_dir = os.path.dirname(OUTPUT_FILE)
        if output_dir and not os.path.exists(output_dir):
             os.makedirs(output_dir)
             print(f"Created output directory: {output_dir}")

        with open(OUTPUT_FILE, 'w') as f:
            json.dump(all_levels_data, f, indent=4)
        print("Successfully created JSON dataset.")
    except IOError as e:
        print(f"Error writing JSON file: {e}")
    except Exception as e:
        print(f"An unexpected error occurred during JSON writing: {e}")
else:
    print("\nNo levels were successfully processed, JSON file will not be created.")
# Out:
# Searching for .txt files in:
# - /home/pressprexx/Code/AKCITGaming/Paper_LLM_PCG_Geral/VGLC_LLM_Finetunning/TheVGLC/Lode Runner/Processed
# Found 150 .txt files.
#
# Processing file 1/150: Level 1.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 2/150: Level 10.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 3/150: Level 100.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 4/150: Level 101.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 5/150: Level 102.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 6/150: Level 103.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 7/150: Level 104.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 8/150: Level 105.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 9/150: Level 106.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 10/150: Level 107.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 11/150: Level 108.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 12/150: Level 109.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 13/150: Level 11.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 14/150: Level 110.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 15/150: Level 111.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 16/150: Level 112.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 17/150: Level 113.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 18/150: Level 114.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 19/150: Level 115.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 20/150: Level 116.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 21/150: Level 117.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 22/150: Level 118.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 23/150: Level 119.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 24/150: Level 12.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 25/150: Level 120.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 26/150: Level 121.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 27/150: Level 122.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 28/150: Level 123.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 29/150: Level 124.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 30/150: Level 125.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 31/150: Level 126.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 32/150: Level 127.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 33/150: Level 128.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 34/150: Level 129.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 35/150: Level 13.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 36/150: Level 130.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 37/150: Level 131.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 38/150: Level 132.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 39/150: Level 133.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 40/150: Level 134.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 41/150: Level 135.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 42/150: Level 136.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 43/150: Level 137.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 44/150: Level 138.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 45/150: Level 139.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 46/150: Level 14.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 47/150: Level 140.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 48/150: Level 141.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 49/150: Level 142.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 50/150: Level 143.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 51/150: Level 144.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 52/150: Level 145.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 53/150: Level 146.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 54/150: Level 147.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 55/150: Level 148.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 56/150: Level 149.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 57/150: Level 15.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 58/150: Level 150.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 59/150: Level 16.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 60/150: Level 17.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 61/150: Level 18.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 62/150: Level 19.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 63/150: Level 2.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 64/150: Level 20.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 65/150: Level 21.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 66/150: Level 22.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 67/150: Level 23.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 68/150: Level 24.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 69/150: Level 25.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 70/150: Level 26.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 71/150: Level 27.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 72/150: Level 28.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 73/150: Level 29.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 74/150: Level 3.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 75/150: Level 30.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 76/150: Level 31.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 77/150: Level 32.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 78/150: Level 33.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 79/150: Level 34.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 80/150: Level 35.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 81/150: Level 36.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 82/150: Level 37.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 83/150: Level 38.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 84/150: Level 39.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 85/150: Level 4.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 86/150: Level 40.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 87/150: Level 41.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 88/150: Level 42.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 89/150: Level 43.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 90/150: Level 44.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 91/150: Level 45.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 92/150: Level 46.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 93/150: Level 47.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 94/150: Level 48.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 95/150: Level 49.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 96/150: Level 5.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 97/150: Level 50.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 98/150: Level 51.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 99/150: Level 52.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 100/150: Level 53.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 101/150: Level 54.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 102/150: Level 55.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 103/150: Level 56.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 104/150: Level 57.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 105/150: Level 58.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 106/150: Level 59.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 107/150: Level 6.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 108/150: Level 60.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 109/150: Level 61.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 110/150: Level 62.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 111/150: Level 63.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 112/150: Level 64.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 113/150: Level 65.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 114/150: Level 66.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 115/150: Level 67.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 116/150: Level 68.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 117/150: Level 69.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 118/150: Level 7.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 119/150: Level 70.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 120/150: Level 71.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 121/150: Level 72.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 122/150: Level 73.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 123/150: Level 74.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 124/150: Level 75.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 125/150: Level 76.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 126/150: Level 77.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 127/150: Level 78.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 128/150: Level 79.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 129/150: Level 8.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 130/150: Level 80.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 131/150: Level 81.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 132/150: Level 82.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 133/150: Level 83.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 134/150: Level 84.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 135/150: Level 85.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 136/150: Level 86.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 137/150: Level 87.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 138/150: Level 88.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 139/150: Level 89.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 140/150: Level 9.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 141/150: Level 90.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 142/150: Level 91.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 143/150: Level 92.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 144/150: Level 93.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 145/150: Level 94.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 146/150: Level 95.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 147/150: Level 96.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 148/150: Level 97.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 149/150: Level 98.txt
# Processing level with original dimensions: 22 height x 32 width.
#
# Processing file 150/150: Level 99.txt
# Processing level with original dimensions: 22 height x 32 width.
# Successfully processed 150 out of 150 files.
#
# Writing data to lode_runner.json...
# Successfully created JSON dataset.
